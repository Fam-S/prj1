# %% [markdown]
# # Best Selling Books Analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Quick Information about All DATA

# %%
Data = pd.read_csv(r"C:\Users\delta co\Documents\Liberaries\DataSets\bestsellers with categories.csv")
Data
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
Data.info() #no nulls data is clean
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550 entries, 0 to 549
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         550 non-null    object
#  1   Author       550 non-null    object
#  2   User Rating  550 non-null    float64
#  3   Reviews      550 non-null    int64
#  4   Price        550 non-null    int64
#  5   Year         550 non-null    int64
#  6   Genre        550 non-null    object
# dtypes: float64(1), int64(3), object(3)
# memory usage: 30.2+ KB

# %%
Data.describe(include='O') #normal => count , mean ,std,min,....
# Out:
#                                                      Name       Author  \
# count                                                 550          550
# unique                                                351          248
# top     Publication Manual of the American Psychologic...  Jeff Kinney
# freq                                                   10           12
#
#               Genre
# count           550
# unique            2
# top     Non Fiction
# freq            310

# %%
Data['Author'].value_counts()
# Out:
# Jeff Kinney                           12
# Suzanne Collins                       11
# Rick Riordan                          11
# Gary Chapman                          11
# American Psychological Association    10
#                                       ..
# Edward Klein                           1
# Khaled Hosseini                        1
# Chrissy Teigen                         1
# Michael Wolff                          1
# Silly Bear                             1
# Name: Author, Length: 248, dtype: int64

# %%
temp_df1 = Data.groupby('Author').count().reset_index().sort_values('Name', ascending = False).head(30)
plt.figure(figsize = (9, 6))

plt.bar(temp_df1['Author'], temp_df1['Name'], color="pink", edgecolor='black')

plt.title('Top 10 Authors with Most Bestsellers')
plt.xlabel('Author')
plt.ylabel('N. Of Books')
plt.xticks(rotation=45, ha='right')


plt.tight_layout()

plt.show()

# %%
Data['Name'].value_counts()[Data['Name'].value_counts()>1]
# Out:
# Publication Manual of the American Psychological Association, 6th Edition                                    10
# StrengthsFinder 2.0                                                                                           9
# Oh, the Places You'll Go!                                                                                     8
# The Very Hungry Caterpillar                                                                                   7
# The 7 Habits of Highly Effective People: Powerful Lessons in Personal Change                                  7
#                                                                                                              ..
# The Shack: Where Tragedy Confronts Eternity                                                                   2
# Quiet: The Power of Introverts in a World That Can't Stop Talking                                             2
# ...

# %% [markdown]
# Sample

# %%
Da_Sample = Data.head(100)
Da_Sample
# Out:
#                                                  Name  \
# 0                       10-Day Green Smoothie Cleanse
# 1                                   11/22/63: A Novel
# 2             12 Rules for Life: An Antidote to Chaos
# 3                              1984 (Signet Classics)
# 4   5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                ...
# 95                           Eclipse (Twilight Sagas)
# 96                                 Eclipse (Twilight)
# 97                                 Educated: A Memoir
# 98                                 Educated: A Memoir
# 99  Enchanted Forest: An Inky Quest and Coloring b...
#
#                       Author  User Rating  Reviews  Price  Year        Genre
# 0                   JJ Smith          4.7    17350      8  2016  Non Fiction
# 1               Stephen King          4.6     2052     22  2011      Fiction
# 2         Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# ...

# %%
#sort by user rating
Da_Sample.sort_values(by='User Rating')
# Out:
#                                                  Name            Author  \
# 22                                          Allegiant     Veronica Roth
# 27                Autobiography of Mark Twain, Vol. 1        Mark Twain
# 62  Dead Reckoning (Sookie Stackhouse/True Blood, ...  Charlaine Harris
# 53      Crazy Rich Asians (Crazy Rich Asians Trilogy)        Kevin Kwan
# 61  Dead in the Family (Sookie Stackhouse/True Blo...  Charlaine Harris
# ..                                                ...               ...
# 85  Dog Man: Fetch-22: From the Creator of Captain...        Dav Pilkey
# 84  Dog Man: Brawl of the Wild: From the Creator o...        Dav Pilkey
# 83  Dog Man: Brawl of the Wild: From the Creator o...        Dav Pilkey
# 87  Dog Man: Lord of the Fleas: From the Creator o...        Dav Pilkey
# 82  Dog Man: A Tale of Two Kitties: From the Creat...        Dav Pilkey
#
#     User Rating  Reviews  Price  Year        Genre
# 22          3.9     6310     13  2013      Fiction
# ...

# %%
val = Da_Sample['Year'].value_counts().values
idx = Da_Sample['Year'].value_counts().index


plt.pie(val ,labels =idx ,autopct='%1.2f%%' , explode=(0.2, 0.1, 0.2, 0.2, 0.1, 0.2, 0.2, 0.3, 0.1, 0.2, 0.3))

plt.title("Publication Ternds")

plt.show()

# %% [markdown]
# Series Of Books

# %%
series = Da_Sample['Name'].value_counts()[Da_Sample['Name'].value_counts()>1]
series
# Out:
# Dear Zoo: A Lift-the-Flap Book                                                                        4
# Crazy Love: Overwhelmed by a Relentless God                                                           3
# Catching Fire (The Hunger Games)                                                                      3
# Becoming                                                                                              2
# Eat to Live: The Amazing Nutrient-Rich Program for Fast and Sustained Weight Loss, Revised Edition    2
# Educated: A Memoir                                                                                    2
# All the Light We Cannot See                                                                           2
# Diagnostic and Statistical Manual of Mental Disorders, 5th Edition: DSM-5                             2
# Dog Man: Brawl of the Wild: From the Creator of Captain Underpants (Dog Man #6)                       2
# ...

# %%
for i in list(series.index):
    display(Da_Sample[Da_Sample['Name']==i])
# Out:
#                               Name        Author  User Rating  Reviews  Price  \
# 63  Dear Zoo: A Lift-the-Flap Book  Rod Campbell          4.8    10922      5
# 64  Dear Zoo: A Lift-the-Flap Book  Rod Campbell          4.8    10922      5
# 65  Dear Zoo: A Lift-the-Flap Book  Rod Campbell          4.8    10922      5
# 66  Dear Zoo: A Lift-the-Flap Book  Rod Campbell          4.8    10922      5
#
#     Year    Genre
# 63  2015  Fiction
# 64  2016  Fiction
# 65  2017  Fiction
# 66  2018  Fiction
#                                            Name        Author  User Rating  \
# 50  Crazy Love: Overwhelmed by a Relentless God  Francis Chan          4.7
# 51  Crazy Love: Overwhelmed by a Relentless God  Francis Chan          4.7
# 52  Crazy Love: Overwhelmed by a Relentless God  Francis Chan          4.7
#
#     Reviews  Price  Year        Genre
# 50     1542     14  2009  Non Fiction
# 51     1542     14  2010  Non Fiction
# 52     1542     14  2011  Non Fiction
# ...

# %% [markdown]
# Genre Analysis

# %%
val2 = Da_Sample['Genre'].value_counts().values
idx2 = Da_Sample['Genre'].value_counts().index

plt.pie(val2 ,labels =idx2 ,autopct='%1.2f%%', colors=['c','m'])

plt.legend()
plt.title("Gerne Parts Percentage")

plt.show()

# %%
# Bar chart for genre analysis
Da_Sample['Genre'].value_counts().plot(kind='bar' ,color ='c')

plt.title('Genre Distribution in Top 100 Bestselling Books')
plt.xlabel('Genre')
plt.ylabel('Number of Books')

plt.show()

# %%
f  = Da_Sample[Da_Sample['Genre']=='Fiction']
nf = Da_Sample[Da_Sample['Genre']=='Non Fiction']

fcount = f['Year'].value_counts()
idx3   = fcount.index
val3   = fcount.values

nfcount = nf['Year'].value_counts()
idx4    = nfcount.index
val4    = nfcount.values

fig ,ax = plt.subplots()
ax.plot(val3,idx3, marker='o',color='c')

ax.set_xlabel('counts',fontsize=15)
ax.set_ylabel('Year',fontsize=15)

ax2=ax.twinx()
ax2.plot(val4,idx4,marker="*",color='g')

ax2.set_ylabel('Year' ,fontsize=15)
fig.legend(['Fiction','Non Fiction'])

plt.show()

# %% [markdown]
# Relations with Reviews

# %%
# Scatter plot for user ratings and reviews
sizes = Da_Sample['Reviews']/600

plt.scatter(x = Da_Sample['User Rating'], y = Da_Sample['Reviews'] ,s = sizes ,alpha = 0.4 ,c = 'black')

plt.title("User Ratings vs Reviews")
plt.xlabel('User Rating')
plt.ylabel('Number of Reviews')

plt.show()

# %%
Re_Sorted = Da_Sample.sort_values(by=['Reviews'], ascending=False).head(25)

plt.figure(figsize = (8, 6))

plt.bar(Re_Sorted['Author'], Re_Sorted['Reviews'], color='purple')

plt.title('Relation Between Author & Reviews')
plt.xlabel('Author Name')
plt.ylabel('N.Reviews')
plt.xticks(rotation=45, ha='right') 

plt.show()

# %% [markdown]
# Books Prices

# %%
# Histogram for book prices

plt.hist(Data['Price'], bins=20, edgecolor='r',color='c')

plt.title('Distribution of Book Prices')
plt.xlabel('Price (USD)')
plt.ylabel('Number of Books')

plt.show()
